# %% [markdown]
# <a href="https://colab.research.google.com/github/psrana/Data-Visualization-using-Matplotlib/blob/main/Data_Visualization_using_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Data Visualization using Matplotlib**
# ---
# ### Data Visualization
# 1. Graphical representation of information and data
# 2. Graph, Chart, and Map make it easier to understand the patterns in data
# 3. Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# 4. Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# ##### Self Learning Resource
# 1. Matplotlib: <a href="https://matplotlib.org/stable/gallery/index.html"> Examples</a>
# 2. Seaborn: <a href="https://seaborn.pydata.org/examples/index.html"> Examples</a>
# 3. Data visualization using matplotlib, seaborn, plotly - <a href="https://www.kaggle.com/abhishekvaid19968/data-visualization-using-matplotlib-seaborn-plotly"> Click Here </a>

# %% [markdown]
# ---
# # **Import matplolib**
# ---

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# # **1. Line plot**
# ---
# ### **1.1 Plot a line**

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y = [i **2 for i in x ]

plt.plot(x, y)

plt.show()

# %% [markdown]
# ---
# ### **1.2 To save plot in a file**
# ---

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y = [i **2 for i in x ]

plt.plot(x, y)

plt.savefig("testImage.png", dpi=100)
#plt.savefig("testImage.jpg", dpi=300)

plt.show()

# %% [markdown]
# ---
# ### **1.3 Download image to local**
# ---

# %%
from google.colab import files
files.download('testImage.png')

# %% [markdown]
# ---
# ### **1.4 Plot a line with details**
# ---

# %%
x = [5, 2, 7]
y = [2, 16, 4]

plt.plot(x, y)
#plt.plot(y,x)

plt.title('This is Title')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# ---
# ### **1.5 Plot multiple lines**
# ---

# %%
x  = [1, 2, 3, 4, 5]
y1 = [50, 40, 70, 80, 20]
y2 = [80, 20, 20, 50, 60]
y3 = [70, 20, 60, 40, 60]
y4 = [80, 20, 20, 50, 60]

plt.plot(x, y1, 'g', label='Enfield', linewidth=2)
plt.plot(x, y2, 'c', label='Honda', linewidth=1)
plt.plot(x, y3, 'k', label='Yahama', linewidth=3)
plt.plot(x, y4, 'y', label='KTM', linewidth=2)

plt.title('Bike details in line plot')
plt.ylabel('Distance in kms')
plt.xlabel('Days')

plt.legend()           #Adding Legends

plt.show()

# %% [markdown]
# ---
# ### **1.6 Mini Project-3 Plot** (Time taken to convert text file to upper case)
# ---

# %%
x  = [1, 2, 3, 4, 5]
y1 = [50, 60, 70, 80, 90]
y2 = [52, 63, 74, 85, 96]
y3 = [54, 66, 78, 90, 102]
y4 = [60, 75, 95, 120, 150]
y5 = [65, 85, 105, 135, 185]

plt.plot(x, y1, 'g', label='C', linewidth=2)
plt.plot(x, y2, 'c', label='C++', linewidth=1)
plt.plot(x, y3, 'k', label='Java', linewidth=3)
plt.plot(x, y4, 'y', label='Perl', linewidth=2)
plt.plot(x, y5, 'r', label='Python', linewidth=2)

plt.title('Performance of Different Programming Languages')
plt.ylabel('Time Taken (sec)')
plt.xlabel('File Size (GB)')

plt.legend()           #Adding Legends

plt.show()

# %% [markdown]
# ---
# # **2. Bar plot**
# ---
# ### **2.1 Plot a bar chart**

# %%
x = [50, 60, 30, 70, 20]
y = ["A", "B", "C", "D", "E"]

plt.bar(y, x, color = "green")

plt.show()

# %% [markdown]
# ---
# ### **2.2 Plot a bar chart with details**
# ---

# %%
import random as r

x = [ r.randint(35,95) for i in range(5)]
y = ["A", "B", "C", "D", "E"]

plt.bar(y, x, color = "blue")

plt.title('Student Performance in EST')
plt.ylabel('Marks in EST')
plt.xlabel('Student')

plt.show()

# %% [markdown]
# ---
# ### **2.3 Multiple bar plot - Example - 1**
# ---

# %%
x1 = [0.25, 1.25, 2.25, 3.25, 4.25]
y1 = [50, 40, 70, 80, 20]

plt.bar(x1, y1, label="BMW", color='r')

x2 = [.75, 1.75, 2.75, 3.75, 4.75]
y2 = [80, 20, 20, 50, 60]
plt.bar(x2, y2, label="Audi", color='y')

plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Information')

plt.legend()
plt.show()

# %% [markdown]
# ---
# ### **2.4 Multiple bar plot - Example - 2**
# ---

# %%
x1 = [0.25, 1.25, 2.25, 3.25, 4.25]
y1 = [50, 40, 70, 80, 20]
plt.bar(x1, y1, label="Enfield", width=0.5)

x2 = [0.26, 1.25, 2.25, 3.25, 4.25]
y2 = [80, 20, 20, 50, 60]
plt.bar(x2, y2, label="Honda", color='r', width=.5)

x3 = [0.31, 1.5, 2.5, 3.5, 4.5]
y3 = [70, 20, 60, 40, 60]
plt.bar(x3, y3, label="Yamaha", color='y', width=.5)

x4 = [.75, 1.75, 2.75, 3.75, 4.75]
y4 = [80, 20, 20, 50, 60]
plt.bar(x4, y4, label="KTM", color='g', width=.5)

plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')

plt.title('Bikes details in BAR PLOTTING')

plt.show()

# %% [markdown]
# ---
# ### **2.5 Horizontal Bar Plot (barh)**
# ---

# %%
x = [5, 6, 3, 7, 2]
y = ["A", "B", "C", "D", "E"]

plt.barh(y, x, color ="orange")

plt.show()

# %% [markdown]
# ---
# # **3. Scatter plot**
# ---
# ### **3.1 Simple Scatter plot**

# %%
x = [5, 2, 9, 4, 7]     # x-axis values 
y = [10, 5, 8, 4, 2]    # Y-axis values 

plt.scatter(x, y)       # Function to plot scatter 

plt.show()              # function to show the plot

# %% [markdown]
# ---
# ### **3.2 Scatter plot with detail**
# ---

# %%
x = [35, 20, 29, 40, 57]     		# x-axis values 
y = [100, 50, 80, 40, 200]      # Y-axis values 

plt.scatter(x, y)         			# Function to plot scatter 

plt.xlabel('Salary * 1000')
plt.ylabel('Age)')
plt.title('Age Vs Salary')

plt.show()               				# function to show the plot

# %% [markdown]
# ---
# ### **3.3 Multiple scatter plot**
# ---

# %%
x1 = [1, 1.5, 2, 2.5, 3, 3.5, 3.6]
y1 = [7.5, 8, 8.5, 9, 9.5, 10, 10.5]

x2 = [8, 8.5, 9, 9.5, 10, 10.5, 11]
y2 = [3, 3.5, 3.7, 4, 4.5, 5, 5.2]

plt.scatter(x1, y1, label='High income low saving',  color='r')
plt.scatter(x2, y2, label='Low income high savings', color='b')

plt.xlabel('Saving*100')
plt.ylabel('Income*1000')
plt.title('Scatter Plot')

plt.legend()

plt.grid()
plt.show()

# %% [markdown]
# ---
# # **4. Pie plot**
# ---
# ### **4.1 Simple Pie plot**

# %%
grades = 'A', 'A-', 'B', 'B-', 'C', 'E'
gradeCount = [50, 60, 140, 160, 30, 20]

plt.pie(gradeCount, labels=grades, autopct='%1.1f%%')

plt.show()

# Question: What is the output?
# print(type(grades))

# %% [markdown]
# ---
# ### **4.2 Pie plot - Explode - 1**
# ---

# %%
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.2, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)

plt.axis('equal')
plt.show()

# %% [markdown]
# ---
# ### **4.3 Pie plot - Explode - 2**
# ---

# %%
share = [3,4,2,1]
bikes = ['Enfield','Honda','Yahama','KTM']

plt.pie(share, labels=bikes, shadow= True, explode=(0,0.1,0,0), 
        autopct='%1.1f%%')

plt.title('Bike Shares')

plt.show()

# %% [markdown]
# ---
# # **5 Working with user Dataset**
#
# ---
# ### **5.1 Download NBA Dataset**
#
# <a href="https://drive.google.com/file/d/1L7rgbbV4I10J28eRWq0oUMNVoDMSaYwo/view?usp=sharing">Click Here</a> to download NBA Dataset

# %% [markdown]
# ---
# ### **5.2 Upload "user file" to "content" directory of Google Colab**
# ---
#
# - Step 1: On Left Side, click on Directory icon
# - Step 2: Click on Content
# - Step 3: Click on Three Dots and upload

# %% [markdown]
# ---
# ### **5.3 Read NBA Dataset**
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('nbaDataset.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ---
# ### **5.4 Read sample data of Google Colab**
# ---
# - Content --> sample_data --> Right Click on File --> Copy path

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/content/sample_data/california_housing_test.csv')
df1.head()
#df1.tail()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# ---
# ### **5.5 Read data file from Google Drive**
# ---
# - Click on "Mount Drive" icon

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/nbaDataset/nbaDataset.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ---
# ### **5.6 Bar graph**
# ---

# %%
x = df['Age']
y = df['Salary']

plt.xlabel('Age')                                   
plt.ylabel('Salary (in millions)')
plt.title('Salary Vs Age')

plt.bar(x, y, color = "purple")

plt.show()

# %% [markdown]
# ---
# ### **5.7 Horizontal bar graph**
# ---

# %%
x = df['Age']
y = df['Salary']

plt.xlabel('Age')                                   
plt.ylabel('Salary (in millions)')
plt.title('Salary Vs Age')

plt.barh(x, y, color = "green")

plt.show()

# %% [markdown]
# ---
# ### **5.8 Scatter plot**
# ---

# %%
x = df['Age']
y = df['Salary']

plt.xlabel('Age')                                   
plt.ylabel('Salary (in millions)')
plt.title('Salary Vs Age')

plt.scatter(x, y, marker = "*")

# marker {'o','+','x','^','*','_'}

plt.show()

# %% [markdown]
# ---
# # **6 Plotting Mathematical Functions**
# ---
# ### **6.1 Plot sine curve**

# %%
# Compute the x and y coordinates for points on a sine curve 
import math as m
import random as r

x = [ m.pi * i  for i in range(0, 10)]
y = [ m.sin(i) for i in x ]

plt.plot(x, y)
plt.title("sin(pi) wave form")

plt.show()

# %% [markdown]
# ---
# ### **6.2 Plot sine wave**
# ---

# %%
import numpy as np

# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 

plt.plot(x, y) 
plt.title("Sine wave form")

plt.show()

# %% [markdown]
# ---
# ### **6.3 Plot cos wave**
# ---

# %%
import numpy as np

# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.cos(x) 

plt.plot(x, y) 
plt.title("Cos wave form")

plt.show()

# %% [markdown]
# ---
# # **7 Subplot**
# ---
# ### **7.1 Example-1**

# %%
import numpy as np

# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 

y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
plt.plot(x, y_cos,'g--') 
plt.plot(x, y_sin,'r--') 
plt.title('Sine and Cosine')  
   
plt.show()

# %% [markdown]
# ---
# ### **7.2 Example-2**
# ---

# %%
import numpy as np

x = np.arange(0, 5 * np.pi, 0.1) 

y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, and 
#     set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
plt.show()

# %% [markdown]
# ---
# # **8 Box Plot**
# ---
# ### **8.1 Data Generation**

# %%
import numpy as np

data = [np.random.normal(0, std, 100) for std in range(1, 4)]

data
# Out:
# [array([ 0.79623227, -0.67686023,  0.81412055, -1.32452874, -0.77260932,
#         -1.73222376, -0.04946527, -0.59186658, -0.39609325, -2.4014089 ,
#         -0.6850853 ,  0.15281355,  0.13696876,  1.6419255 , -0.46792088,
#          0.29005411,  0.31486673, -0.00533341,  1.6849984 , -0.35704718,
#          0.99720092,  1.96473002,  0.59147319, -1.15732706,  0.04504884,
#          0.24521603,  0.51861158, -1.60973879, -1.14292063, -0.17893544,
#          2.15007869,  0.33924641, -0.49734558, -1.85300989, -0.75402409,
#          2.01250157, -0.85846561, -0.64640677,  0.62163169, -1.33653398,
#         -0.03491891, -0.64647693,  1.57211264, -0.40428443, -1.61285813,
#         -0.54960969,  0.96650979, -1.19838723,  0.54290462,  1.70504403,
#          1.06759134,  0.34732513, -0.91310649,  1.11676352, -0.60364649,
#          0.57616075,  1.48836469, -0.24769338,  0.0453241 ,  1.19426896,
#          0.2740392 , -0.37821812,  0.48556972,  0.04611327, -1.00773593,
#          1.57013099, -0.39040877, -1.11671999, -1.62628427, -0.3703389 ,
#          0.29620387,  0.19455735, -1.01540658,  0.53050559, -0.13886157,
#         -1.25972802,  0.23059359, -1.5399367 , -0.13653111,  0.49716207,
#         -1.86042332,  0.91629097, -1.56388525, -0.70622409, -0.19138108,
#          0.06048883,  0.98743145,  2.09654358, -0.22152373, -0.31165221,
#          0.87970362, -1.69566448,  0.2186525 ,  0.01185125, -0.1600996 ,
#         -1.44337464,  0.25481575, -1.20976706,  0.58134691, -1.21596035]),
#  array([-0.72231835,  0.47789169,  0.71855008, -0.40506303,  0.10298205,
#         -2.44148654, -2.22482259,  0.54889586, -1.07840909,  0.59795818,
#         -1.64010545,  2.2884779 , -1.07002863, -1.07530877, -1.89747078,
#         -2.34290149, -0.22147217,  0.21103151, -0.3188284 , -1.41754204,
#          0.09914292, -2.5923311 ,  4.86272974,  0.44118655, -1.45036375,
#         -0.55405961,  0.69057291, -2.51220236,  2.72258741,  1.66616665,
#         -1.03377952, -2.05152613,  1.78082015, -0.92476968,  1.84096646,
#          2.52744948,  1.39800274, -3.51451374,  0.14512781,  0.97188978,
#          1.8218581 ,  0.75093167, -0.16975932, -0.64602146,  0.63638526,
#          2.61016919, -0.17464921, -0.10379141,  4.45000891, -2.33403828,
#          2.10034203,  0.8533087 ,  2.22648117, -3.03189388, -0.38899171,
#          1.03326167, -0.33540978, -1.96308032, -0.6780122 , -0.63867796,
#         -0.58644312, -2.30420881,  2.24883399,  1.4663598 , -0.82551731,
#         -1.96863785, -0.04907495, -2.31537343,  0.21971935,  0.04229716,
#         -1.29872646,  0.50279177,  1.90136792,  1.0694196 ,  0.75028181,
#          0.66042131, -0.0294187 , -1.42577126, -2.174433  , -2.02029805,
#         -2.03382293, -2.17622277, -1.47737782,  0.78245683,  0.12590315,
#          0.58215148,  1.21886399, -2.55247912,  0.73996551,  0.77345659,
#          2.00665003, -0.58082933, -1.34884309, -0.83717435, -1.53819937,
#          0.57757896, -4.36368579, -0.49814754,  1.44394901,  0.54637391]),
#  array([ 0.54538501,  1.13849978,  4.63078708,  1.19571076, -1.43726282,
#         -2.04011125, -2.24052096,  2.06051688,  1.10466048, -6.58850498,
#         -1.29342922, -3.72760865, -2.61528378,  2.40682039, -0.07101779,
#          1.16512341, -2.02903174, -2.58660337, -3.76802841,  0.21234025,
#          1.14104667,  3.69729753, -1.15394505,  0.09885648,  2.12687488,
#         -3.3188061 , -0.10950224,  4.16140043,  0.38413481, -3.57510037,
#         -2.90551482, -0.60355933, -0.18352129, -1.00704382,  3.28059084,
#         -1.87033701,  2.04753418, -0.38272931, -2.03020324,  3.75150218,
#          1.30043057, -1.83305725, -4.44289482,  0.10811078,  2.61345302,
#          1.39875002, -1.40493689, -0.25000067, -2.77793623, -0.11646985,
#          6.56586661,  8.40793765, -0.10687265, -6.21193592,  6.74447067,
#         -5.23000564, -3.65077722, -7.48667296,  4.82875466, -3.70374015,
#          3.65641801, -2.2121597 , -6.3440783 ,  1.17123679,  3.03621651,
#          1.87477447, -2.8814991 , -0.91288788,  2.16421629, -0.41172829,
#         -3.16180183, -2.18411241, -1.37029736,  2.72409676,  1.44449806,
#         -4.3301141 , -5.01003119, -1.69831164, -5.43762845, -5.38334484,
#          4.30767584,  0.40706678,  0.04231502,  5.4576924 , -1.46723553,
#          5.02111074, -6.27983973,  1.77799648,  3.05172866, -3.00633853,
#          2.51563359, -0.72684147, -3.30697891,  2.15126922, -0.14025461,
#         -7.60882656,  0.03496729,  1.02036716, -1.58100058, -1.65499263])]

# %% [markdown]
# ---
# ### **8.2 Box Plot - Vertical**
# ---

# %%
import matplotlib.pyplot as plt

plt.boxplot(data)
plt.show()

# %% [markdown]
# ---
# ### **8.3 Box Plot - Horizontal**
# ---

# %%
import matplotlib.pyplot as plt

plt.boxplot(data ,vert=False)
plt.show()

# %% [markdown]
# ---
# # **9 Plot Time Series**
# ---
# ### **9.1 Import libraries**

# %%
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ---
# ### **9.2 Download timeSeries Dataset and upload it to Google drive**
#
# <a href="https://drive.google.com/file/d/1vAhUzlSOIWjNz7dlk6_jmR1VKq-Ui6Id/view?usp=sharing">Click Here</a> to download timeSeries Dataset

# %% [markdown]
# ### **9.3 Read Time Series Dataset**

# %%
series = read_csv('/content/drive/MyDrive/timeSeriesDataset/timeSeriesDataset.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.head(15)
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# 1981-01-06    15.8
# 1981-01-07    15.8
# 1981-01-08    17.4
# 1981-01-09    21.8
# 1981-01-10    20.0
# 1981-01-11    16.2
# 1981-01-12    13.3
# 1981-01-13    16.7
# 1981-01-14    21.5
# 1981-01-15    25.0
# Name: Temp, dtype: float64

# %% [markdown]
# ### **9.4 Minimum Daily Temperature Line Plot**

# %%
series.plot()
pyplot.show()

# %% [markdown]
# ### **9.5 Minimum Daily Temperature Dot Plot**

# %%
series.plot(style='k.')
pyplot.show()

# %% [markdown]
# ### **9.6 Minimum Daily Temperature Yearly Line Plots**

# %%
from pandas import DataFrame
from pandas import Grouper

groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.plot(subplots=True, legend=False)
pyplot.show()

# %% [markdown]
# ### **9.7 Minimum Daily Temperature Histogram Plot**

# %%
series.hist()
pyplot.show()

# %% [markdown]
# ### **9.8 Minimum Daily Temperature Density Plot**

# %%
series.plot(kind='kde')
pyplot.show()

# %% [markdown]
# ### **9.9 Minimum Daily Temperature Yearly Box and Whisker Plots**

# %%
from pandas import DataFrame
from pandas import Grouper
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.boxplot()
pyplot.show()

# %% [markdown]
# ### **9.10 Minimum Daily Temperature Yearly Heat Map Plot**

# %%
from pandas import Grouper
from matplotlib import pyplot
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years = years.T
pyplot.matshow(years, interpolation=None, aspect='auto')
pyplot.show()

# %% [markdown]
# ### **9.11 Minimum Daily Temperature Lag Plot**

# %%
from pandas.plotting import lag_plot
lag_plot(series)
pyplot.show()

# %% [markdown]
# ### **9.12 Minimum Daily Temperature Autocorrelation Plot**

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
pyplot.show()
